# %% [markdown]
# # Google Playstore

# %% [markdown]
# # Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
for i in df.columns:
    print(df[i].unique())
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook' 'Coloring book moana'
#  'U Launcher Lite – FREE Live Cool Themes, Hide Apps' ...
#  'Parkinson Exercices FR' 'The SCP Foundation DB fr nn5n'
#  'iHoroscope - 2018 Daily Horoscope & Astrology']
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']
# [ 4.1  3.9  4.7  4.5  4.3  4.4  3.8  4.2  4.6  3.2  4.   nan  4.8  4.9
#   3.6  3.7  3.3  3.4  3.5  3.1  5.   2.6  3.   1.9  2.5  2.8  2.7  1.
#   2.9  2.3  2.2  1.7  2.   1.8  2.4  1.6  2.1  1.4  1.5  1.2 19. ]
# ['159' '967' '87510' ... '603' '1195' '398307']
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.sample()
# Out:
#                 App   Category  Rating Reviews Size Installs  Type Price  \
# 4640  Kicker U Lite  LIFESTYLE     4.1     438  26M  50,000+  Free     0
#
#      Content Rating     Genres        Last Updated Current Ver Android Ver
# 4640       Everyone  Lifestyle  September 27, 2013       2.0.0  2.1 and up

# %%
sns.boxplot(y=df.Category,x=df.Rating)
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Category'>

# %%
df.groupby('Category')['Rating'].mean()
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# AUTO_AND_VEHICLES       4.190411
# BEAUTY                  4.278571
# BOOKS_AND_REFERENCE     4.346067
# BUSINESS                4.121452
# COMICS                  4.155172
# COMMUNICATION           4.158537
# DATING                  3.970769
# EDUCATION               4.389032
# ENTERTAINMENT           4.126174
# EVENTS                  4.435556
# FAMILY                  4.192272
# FINANCE                 4.131889
# FOOD_AND_DRINK          4.166972
# GAME                    4.286326
# HEALTH_AND_FITNESS      4.277104
# HOUSE_AND_HOME          4.197368
# LIBRARIES_AND_DEMO      4.178462
# LIFESTYLE               4.094904
# MAPS_AND_NAVIGATION     4.051613
# MEDICAL                 4.189143
# NEWS_AND_MAGAZINES      4.132189
# PARENTING               4.300000
# PERSONALIZATION         4.335987
# PHOTOGRAPHY             4.192114
# PRODUCTIVITY            4.211396
# SHOPPING                4.259664
# ...

# %%
df.groupby('Category')['Rating'].min()
# Out:
# Category
# 1.9                    19.0
# ART_AND_DESIGN          3.2
# AUTO_AND_VEHICLES       2.1
# BEAUTY                  3.1
# BOOKS_AND_REFERENCE     2.7
# BUSINESS                1.0
# COMICS                  2.8
# COMMUNICATION           1.0
# DATING                  1.0
# EDUCATION               3.5
# ENTERTAINMENT           3.0
# EVENTS                  2.9
# FAMILY                  1.0
# FINANCE                 1.0
# FOOD_AND_DRINK          1.7
# GAME                    1.0
# HEALTH_AND_FITNESS      1.4
# HOUSE_AND_HOME          2.8
# LIBRARIES_AND_DEMO      3.1
# LIFESTYLE               1.5
# MAPS_AND_NAVIGATION     1.9
# MEDICAL                 1.0
# NEWS_AND_MAGAZINES      1.7
# PARENTING               2.0
# PERSONALIZATION         2.5
# PHOTOGRAPHY             2.0
# PRODUCTIVITY            1.0
# SHOPPING                1.6
# SOCIAL                  1.9
# SPORTS                  1.5
# TOOLS                   1.0
# TRAVEL_AND_LOCAL        2.2
# ...

# %% [markdown]
# # Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
The dataset has missing values.
As Missing values in Rating is 1474, It will not provide us actual findings from the dataset.
# Out:
#   Cell In[104], line 1
#     The dataset has missing values.
#         ^
# SyntaxError: invalid syntax

# %%
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
df['Rating'].isnull().sum()
# Out:
# 1474

# %%
df['Type'].isnull().sum()
# Out:
# 1

# %%
df[df['Type'].isnull()]
# Out:
#                             App Category  Rating Reviews                Size  \
# 9148  Command & Conquer: Rivals   FAMILY     NaN       0  Varies with device
#
#      Installs Type Price Content Rating    Genres   Last Updated  \
# 9148        0  NaN     0   Everyone 10+  Strategy  June 28, 2018
#
#              Current Ver         Android Ver
# 9148  Varies with device  Varies with device

# %%
df[df['Content Rating'].isnull()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df[df['Current Ver'].isnull()]
# Out:
#                                    App             Category  Rating Reviews  \
# 15     Learn To Draw Kawaii Characters       ART_AND_DESIGN     3.2      55
# 1553              Market Update Helper   LIBRARIES_AND_DEMO     4.1   20145
# 6322            Virtual DJ Sound Mixer                TOOLS     4.2    4010
# 6803                         BT Master               FAMILY     NaN       0
# 7333                       Dots puzzle               FAMILY     4.0     179
# 7407                   Calculate My IQ               FAMILY     NaN      44
# 7730                            UFO-CQ                TOOLS     NaN       1
# 10342                   La Fe de Jesus  BOOKS_AND_REFERENCE     NaN       8
#
#        Size    Installs  Type  Price Content Rating             Genres  \
# 15     2.7M      5,000+  Free      0       Everyone       Art & Design
# 1553    11k  1,000,000+  Free      0       Everyone   Libraries & Demo
# ...

# %%
df[df['Android Ver'].isnull()]
# Out:
#                                            App         Category  Rating  \
# 4453                    [substratum] Vacuum: P  PERSONALIZATION     4.4
# 4490                      Pi Dark [substratum]  PERSONALIZATION     4.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 4453      230     11M   1,000+  Paid     $1.49       Everyone
# 4490      189    2.1M  10,000+  Free         0       Everyone
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
#
#                   Genres    Last Updated Current Ver Android Ver
# 4453     Personalization   July 20, 2018         4.4         NaN
# 4490     Personalization  March 27, 2018         1.1         NaN
# 10472  February 11, 2018          1.0.19  4.0 and up         NaN

# %% [markdown]
# # Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
sns.scatterplot(x=df.size,y=df.Rating)
# Out:
# <AxesSubplot: ylabel='Rating'>

# %%
sns.scatterplot(y=df.size,x=df.Rating)
# Out:
# <AxesSubplot: xlabel='Rating'>

# %% [markdown]
# # Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
df.Category.unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Price']=df['Price'].replace({'Everyone':'1'})

# %%
df['Price']=df['Price'].replace({'1':'$1','0':'$0'})

# %%
df['Price'].unique()
# Out:
# array(['$0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99',
#        '$5.99', '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00',
#        '$5.49', '$10.00', '$24.99', '$11.99', '$79.99', '$16.99',
#        '$14.99', '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50',
#        '$19.99', '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49',
#        '$1.70', '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df['Price'].str.split('$').str[1]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10836    0
# 10837    0
# 10838    0
# 10839    0
# 10840    0
# Name: Price, Length: 10841, dtype: object

# %%
df['Price']=df['Price'].str.split('$').str[1]

# %%
df['Price']=df['Price'].astype(float)

# %%
df['Price'].dtypes
# Out:
# dtype('float64')

# %%
df['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB

# %%
df.groupby('App')['Price'].mean()
# Out:
# App
# "i DT" Fútbol. Todos Somos Técnicos.                  0.00
# +Download 4 Instagram Twitter                         0.00
# - Free Comics - Comic Apps                            0.00
# .R                                                    0.00
# /u/app                                                0.00
#                                                      ...
# 뽕티비 - 개인방송, 인터넷방송, BJ방송                               0.00
# 💎 I'm rich                                          399.99
# 💘 WhatsLov: Smileys of love, stickers and GIF         0.00
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!      0.00
# 🔥 Football Wallpapers 4K | Full HD Backgrounds 😍      0.00
# Name: Price, Length: 9660, dtype: float64

# %%
df.groupby('App')['Price'].describe()
# Out:
#                                                   count    mean  std     min  \
# App
# "i DT" Fútbol. Todos Somos Técnicos.                1.0    0.00  NaN    0.00
# +Download 4 Instagram Twitter                       1.0    0.00  NaN    0.00
# - Free Comics - Comic Apps                          1.0    0.00  NaN    0.00
# .R                                                  1.0    0.00  NaN    0.00
# /u/app                                              1.0    0.00  NaN    0.00
# ...                                                 ...     ...  ...     ...
# 뽕티비 - 개인방송, 인터넷방송, BJ방송                             1.0    0.00  NaN    0.00
# 💎 I'm rich                                          1.0  399.99  NaN  399.99
# 💘 WhatsLov: Smileys of love, stickers and GIF       1.0    0.00  NaN    0.00
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!    1.0    0.00  NaN    0.00
# 🔥 Football Wallpapers 4K | Full HD Backgrounds 😍    1.0    0.00  NaN    0.00
#
# ...

# %% [markdown]
# # Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
df['Category'].value_counts().sum()
# Out:
# 10841

# %%
df['Category'].value_counts().sum()
# Out:
# 10841

# %%
df['Category'].nunique()
# Out:
# 34

# %%
pd.DataFrame(df['Category'].value_counts())
# Out:
#                      Category
# FAMILY                   1972
# GAME                     1144
# TOOLS                     843
# MEDICAL                   463
# BUSINESS                  460
# PRODUCTIVITY              424
# PERSONALIZATION           392
# COMMUNICATION             387
# SPORTS                    384
# LIFESTYLE                 382
# FINANCE                   366
# HEALTH_AND_FITNESS        341
# PHOTOGRAPHY               335
# SOCIAL                    295
# NEWS_AND_MAGAZINES        283
# SHOPPING                  260
# TRAVEL_AND_LOCAL          258
# DATING                    234
# BOOKS_AND_REFERENCE       231
# VIDEO_PLAYERS             175
# EDUCATION                 156
# ENTERTAINMENT             149
# MAPS_AND_NAVIGATION       137
# FOOD_AND_DRINK            127
# HOUSE_AND_HOME             88
# LIBRARIES_AND_DEMO         85
# AUTO_AND_VEHICLES          85
# WEATHER                    82
# ART_AND_DESIGN             65
# EVENTS                     64
# ...

# %%
category=pd.DataFrame(df['Category'].value_counts())
category.rename(columns={'Category':'Count'},inplace=True)

# %%
category
# Out:
#                      Count
# FAMILY                1972
# GAME                  1144
# TOOLS                  843
# MEDICAL                463
# BUSINESS               460
# PRODUCTIVITY           424
# PERSONALIZATION        392
# COMMUNICATION          387
# SPORTS                 384
# LIFESTYLE              382
# FINANCE                366
# HEALTH_AND_FITNESS     341
# PHOTOGRAPHY            335
# SOCIAL                 295
# NEWS_AND_MAGAZINES     283
# SHOPPING               260
# TRAVEL_AND_LOCAL       258
# DATING                 234
# BOOKS_AND_REFERENCE    231
# VIDEO_PLAYERS          175
# EDUCATION              156
# ENTERTAINMENT          149
# MAPS_AND_NAVIGATION    137
# FOOD_AND_DRINK         127
# HOUSE_AND_HOME          88
# LIBRARIES_AND_DEMO      85
# AUTO_AND_VEHICLES       85
# WEATHER                 82
# ART_AND_DESIGN          65
# EVENTS                  64
# PARENTING               60
# COMICS                  60
# BEAUTY                  53
# ...

# %%
df.Category.isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=category.index[:10],y='Count',data=category[:10],palette='hls')
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159   19M      10,000+  Free    0.0       Everyone
# 1     967   14M     500,000+  Free    0.0       Everyone
# 2   87510  8.7M   5,000,000+  Free    0.0       Everyone
# 3  215644   25M  50,000,000+  Free    0.0           Teen
# 4     967  2.8M     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
app=pd.DataFrame(df['App'].value_counts())
app.rename(columns={'App':'Count'},inplace=True)

# %%
app
# Out:
#                                                     Count
# ROBLOX                                                  9
# CBS Sports App - Scores, News, Stats & Watch Live       8
# ESPN                                                    7
# Duolingo: Learn Languages Free                          7
# Candy Crush Saga                                        7
# ...                                                   ...
# Meet U - Get Friends for Snapchat, Kik & Instagram      1
# U-Report                                                1
# U of I Community Credit Union                           1
# Waiting For U Launcher Theme                            1
# iHoroscope - 2018 Daily Horoscope & Astrology           1
#
# [9660 rows x 1 columns]

# %%
df['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %%
df['App'].isnull().sum()
# Out:
# 0

# %%
df[['App','Installs']]
# Out:
#                                                      App     Installs
# 0         Photo Editor & Candy Camera & Grid & ScrapBook      10,000+
# 1                                    Coloring book moana     500,000+
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...   5,000,000+
# 3                                  Sketch - Draw & Paint  50,000,000+
# 4                  Pixel Draw - Number Art Coloring Book     100,000+
# ...                                                  ...          ...
# 10836                                   Sya9a Maroc - FR       5,000+
# 10837                   Fr. Mike Schmitz Audio Teachings         100+
# 10838                             Parkinson Exercices FR       1,000+
# 10839                      The SCP Foundation DB fr nn5n       1,000+
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology  10,000,000+
#
# [10841 rows x 2 columns]

# %%
df['Installs']=df['Installs'].str.split('+').str[0]

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size    Installs  Type  Price Content Rating  \
# 0     159   19M      10,000  Free    0.0       Everyone
# 1     967   14M     500,000  Free    0.0       Everyone
# 2   87510  8.7M   5,000,000  Free    0.0       Everyone
# 3  215644   25M  50,000,000  Free    0.0           Teen
# 4     967  2.8M     100,000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Installs'].unique()
# Out:
# array(['10,000', '500,000', '5,000,000', '50,000,000', '100,000',
#        '50,000', '1,000,000', '10,000,000', '5,000', '100,000,000',
#        '1,000,000,000', '1,000', '500,000,000', '50', '100', '500', '10',
#        '1', '5', '0', 'Free'], dtype=object)

# %%
df['Installs']=df['Installs'].replace({'Free':'0'})

# %%
df['Installs'].unique()
# Out:
# array(['10,000', '500,000', '5,000,000', '50,000,000', '100,000',
#        '50,000', '1,000,000', '10,000,000', '5,000', '100,000,000',
#        '1,000,000,000', '1,000', '500,000,000', '50', '100', '500', '10',
#        '1', '5', '0'], dtype=object)

# %%
df['Installs']=df['Installs'].str.replace(',','')

# %%
df['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df['Installs'].dtypes
# Out:
# dtype('O')

# %%
df['Installs']=df['Installs'].astype(int)

# %%
df['Installs'].dtypes
# Out:
# dtype('int64')

# %%
df.groupby('App')['Installs'].mean()
# Out:
# App
# "i DT" Fútbol. Todos Somos Técnicos.                    500.0
# +Download 4 Instagram Twitter                       1000000.0
# - Free Comics - Comic Apps                            10000.0
# .R                                                    10000.0
# /u/app                                                10000.0
#                                                       ...
# 뽕티비 - 개인방송, 인터넷방송, BJ방송                              100000.0
# 💎 I'm rich                                            10000.0
# 💘 WhatsLov: Smileys of love, stickers and GIF       1000000.0
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!      10000.0
# 🔥 Football Wallpapers 4K | Full HD Backgrounds 😍    1000000.0
# Name: Installs, Length: 9660, dtype: float64

# %% [markdown]
# # Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=category.index[:10],y='Count',data=category[:10],palette='hls')
# Out:
# <AxesSubplot: ylabel='Count'>

# %%
The most popular app category in the dataset is Family.
we will find the most popular apps category available in the dataset/google playstore.
we will find the no of Installations/users of that app.
# Out:
#   Cell In[155], line 1
#     The most popular app category in the dataset is Family.
#         ^
# SyntaxError: invalid syntax

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  int64
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
df.groupby('Category')['Installs'].mean()
# Out:
# Category
# 1.9                    0.000000e+00
# ART_AND_DESIGN         1.912894e+06
# AUTO_AND_VEHICLES      6.250613e+05
# BEAUTY                 5.131519e+05
# BOOKS_AND_REFERENCE    8.318050e+06
# BUSINESS               2.178076e+06
# COMICS                 9.347692e+05
# COMMUNICATION          8.435989e+07
# DATING                 1.129533e+06
# EDUCATION              5.586231e+06
# ENTERTAINMENT          1.925611e+07
# EVENTS                 2.495806e+05
# FAMILY                 5.201959e+06
# FINANCE                2.395215e+06
# FOOD_AND_DRINK         2.156683e+06
# GAME                   3.066960e+07
# HEALTH_AND_FITNESS     4.642441e+06
# HOUSE_AND_HOME         1.917187e+06
# LIBRARIES_AND_DEMO     7.411284e+05
# LIFESTYLE              1.407444e+06
# MAPS_AND_NAVIGATION    5.286729e+06
# MEDICAL                1.150269e+05
# NEWS_AND_MAGAZINES     2.648876e+07
# PARENTING              5.253518e+05
# PERSONALIZATION        5.932385e+06
# PHOTOGRAPHY            3.011417e+07
# ...

# %% [markdown]
# # Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %%
I will check the most successfull app developer based on Installments first.
Once it is done then there are several fetures like Category,size,Price will be seen
# Out:
#   Cell In[158], line 1
#     I will check the most successfull app developer based on Installments first.
#       ^
# SyntaxError: invalid syntax

# %%
df.sample(3)
# Out:
#                                 App         Category  Rating Reviews  Size  \
# 6584             iBP Blood Pressure          MEDICAL     4.4     578  704k
# 6716               Bullshit! (Free)             GAME     2.4      45  4.1M
# 7580  OMEGA Black UI Theme - CM 12+  PERSONALIZATION     4.2      12   19M
#
#       Installs  Type  Price Content Rating           Genres  \
# 6584     10000  Paid   0.99       Everyone          Medical
# 6716     10000  Free   0.00           Teen             Card
# 7580       100  Paid   0.99       Everyone  Personalization
#
#            Last Updated Current Ver Android Ver
# 6584  November 30, 2014       7.0.1  2.2 and up
# 6716    August 26, 2016         1.1  4.1 and up
# 7580    August 20, 2015         1.0  5.0 and up

# %%
gk=df.groupby('Category')

# %%
gk.first()
# Out:
#                                                                    App  \
# Category
# 1.9                            Life Made WI-Fi Touchscreen Photo Frame
# ART_AND_DESIGN          Photo Editor & Candy Camera & Grid & ScrapBook
# AUTO_AND_VEHICLES                          Monster Truck Stunt 3D 2019
# BEAUTY                                      Hush - Beauty for Everyone
# BOOKS_AND_REFERENCE                               Wattpad 📖 Free Books
# BUSINESS                                  Visual Voicemail by MetroPCS
# COMICS                                      LINE WEBTOON - Free Comics
# COMMUNICATION                 Messenger – Text and Video Chat for Free
# DATING                                       Moco+ - Chat, Meet People
# EDUCATION                               Duolingo: Learn Languages Free
# ENTERTAINMENT                                                  Netflix
# EVENTS                                              All Events in City
# ...

# %%
gk=df.groupby('Installs')

# %%
gk.first()
# Out:
#                                                           App  \
# Installs
# 0                Popsicle Launcher for Android P 9.0 launcher
# 1                                 Healthy Relationships Guide
# 5                                    Diamond Engagement Rings
# 10                                    House party - live chat
# 50                                          Truth or Dare Pro
# 100           Private Dating, Hide App- Blue for PrivacyHider
# 500                    Cardi B Live Stream Video Chat - Prank
# 1000                             Hojiboy Tojiboyev Life Hacks
# 5000                          Learn To Draw Kawaii Characters
# 10000          Photo Editor & Candy Camera & Grid & ScrapBook
# 50000                              Paper flowers instructions
# 100000                  Pixel Draw - Number Art Coloring Book
# 500000                                    Coloring book moana
# 1000000                                      Infinite Painter
# ...

# %%
df['Type']=df['Type'].dropna(axis=0)

# %%
df['Type'].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %% [markdown]
# # Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type  Price Content Rating  \
# 0     159   19M     10000  Free    0.0       Everyone
# 1     967   14M    500000  Free    0.0       Everyone
# 2   87510  8.7M   5000000  Free    0.0       Everyone
# 3  215644   25M  50000000  Free    0.0           Teen
# 4     967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.shape
# Out:
# (10841, 13)

# %%
df['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
ak=df.groupby('Last Updated')

# %%
ak.first()
# Out:
#                                                        App       Category  \
# Last Updated
# 1.0.19             Life Made WI-Fi Touchscreen Photo Frame            1.9
# April 1, 2016                 DU Browser—Browse fast & fun  COMMUNICATION
# April 1, 2017                             Q*bert: Rebooted           GAME
# April 1, 2018               Latest Emmanuella Comedy Video      PARENTING
# April 10, 2013                   G-Force Driving Assistant         SPORTS
# ...                                                    ...            ...
# September 8, 2016                           Chess PRO Free         FAMILY
# September 8, 2017                        Add Text To Photo    PHOTOGRAPHY
# September 9, 2015           Best Friends Dress Up & Makeup         FAMILY
# September 9, 2016                                     EI国际         FAMILY
# September 9, 2017                         Kim Bu Youtuber?         FAMILY
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  int64
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
df.loc[df['Last Updated']=='1.0.19']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size  Installs Type  Price Content Rating             Genres  \
# 10472  1,000+         0    0    1.0            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df=df.drop(df.index[10472])

# %%
pd.to_datetime(df['Last Updated'])
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10840, dtype: datetime64[ns]

# %%
df['Last Updated']=pd.to_datetime(df['Last Updated'])
df['Day']=pd.to_datetime(df['Last Updated']).dt.day
df['Month']=pd.to_datetime(df['Last Updated']).dt.month
df['Year']=pd.to_datetime(df['Last Updated']).dt.year

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type  Price Content Rating  \
# 0     159   19M     10000  Free    0.0       Everyone
# 1     967   14M    500000  Free    0.0       Everyone
# 2   87510  8.7M   5000000  Free    0.0       Everyone
# 3  215644   25M  50000000  Free    0.0           Teen
# 4     967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df.groupby('App')['Month'].mean()
# Out:
# App
# "i DT" Fútbol. Todos Somos Técnicos.                10.0
# +Download 4 Instagram Twitter                        8.0
# - Free Comics - Comic Apps                           7.0
# .R                                                   9.0
# /u/app                                               7.0
#                                                     ...
# 뽕티비 - 개인방송, 인터넷방송, BJ방송                              7.0
# 💎 I'm rich                                           3.0
# 💘 WhatsLov: Smileys of love, stickers and GIF        7.0
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!    10.0
# 🔥 Football Wallpapers 4K | Full HD Backgrounds 😍     7.0
# Name: Month, Length: 9659, dtype: float64

# %%
df.groupby('App')['Month'].describe()
# Out:
#                                                   count  mean  std   min  \
# App
# "i DT" Fútbol. Todos Somos Técnicos.                1.0  10.0  NaN  10.0
# +Download 4 Instagram Twitter                       1.0   8.0  NaN   8.0
# - Free Comics - Comic Apps                          1.0   7.0  NaN   7.0
# .R                                                  1.0   9.0  NaN   9.0
# /u/app                                              1.0   7.0  NaN   7.0
# ...                                                 ...   ...  ...   ...
# 뽕티비 - 개인방송, 인터넷방송, BJ방송                             1.0   7.0  NaN   7.0
# 💎 I'm rich                                          1.0   3.0  NaN   3.0
# 💘 WhatsLov: Smileys of love, stickers and GIF       1.0   7.0  NaN   7.0
# 📏 Smart Ruler ↔️ cm/inch measuring for homework!    1.0  10.0  NaN  10.0
# 🔥 Football Wallpapers 4K | Full HD Backgrounds 😍    1.0   7.0  NaN   7.0
#
#                                                    25%   50%   75%   max
# App
# ...

# %%
mo=df.groupby('Month')
mo.first()
# Out:
#                                                      App        Category  \
# Month
# 1         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 2                                   Beauty Selfie Camera          BEAUTY
# 3                             Paper flowers instructions  ART_AND_DESIGN
# 4                Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN
# 5                                      Art Drawing Ideas  ART_AND_DESIGN
# 6                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 7                          Kids Paint Free - Drawing Fun  ART_AND_DESIGN
# 8      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 9                                   Garden Coloring Book  ART_AND_DESIGN
# 10                               Text on Photo - Fonteee  ART_AND_DESIGN
# 11                              350 Diy Room Decor Ideas  ART_AND_DESIGN
# 12                 Little Teddy Bear Colouring Book Game  ART_AND_DESIGN
#
# ...
